# %% [markdown]
# <a href="https://colab.research.google.com/github/Adrian-ACI/MetNumUN2021II/blob/master/Lab7/group3AlgorithmicToolboxWeek1Quadratic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CAPTURAS DE PANTALLA

# %% [markdown]
# ESTUDIANTE: Adrian Arturo Canacuan ipial

# %% [markdown]
# UNCODE

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# COURSERA

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ESTUDIANTE: Diego Alejandro Rodriguez Martinez

# %% [markdown]
# ![Captura.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Captura2.PNG](data:image/png;base64,...)
