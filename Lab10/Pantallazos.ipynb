# %% [markdown]
# <a href="https://colab.research.google.com/github/Adrian-ACI/MetNumUN2021II/blob/master/Lab10/Pantallazos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CAPTURAS DE PANTALLA

# %% [markdown]
# ESTUDIANTE: Adrian Arturo Canacuan ipial

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Estudiante:Diego Alejandro Rodriguez Martinez**

# %% [markdown]
# ![Captura.PNG](data:image/png;base64,...)
